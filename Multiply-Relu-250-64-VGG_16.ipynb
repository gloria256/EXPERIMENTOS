# %% [markdown]
# <a href="https://colab.research.google.com/github/gloria256/EXPERIMENTOS/blob/master/Multiplic-plana-250-64-VGG_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CLASIFICADOR BINARIO USANDO LA RED: VGG16**

# %% [markdown]
# ## **1. Librerías necesarias y descarga de la función para la curva ROC en Drive.**

# %%
#IMPORTACION DE LIBRERIAS NECESARIAS
import pandas as pd
import tensorflow_datasets as tfds
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os
from keras.applications.resnet import preprocess_input, decode_predictions
import sklearn

# ACCESO A GOOGLE DRIVE
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#ARCHIVO DE FUNCIONES
file_id = '1QTJIzZb4xL9_it6AF4qpz6KJGIpprIVD' 
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('funciones_people.py') 
from funciones_people import roc_multiclass, roc_auc_mc

# %% [markdown]
# ## **4. Descargar imágenes de CIFAR-10**
#
# consta de 60000 imágenes en color de 32x32 en 10 clases, con 6000 imágenes por clase. Hay 50000 imágenes de entrenamiento y 10000 imágenes de prueba.
#
# El conjunto de datos se divide en cinco lotes de entrenamiento y un lote de prueba, cada uno con 10000 imágenes. El lote de prueba contiene exactamente 1000 imágenes seleccionadas al azar de cada clase.
#
# $avión\hspace{1em}automóvil\hspace{1em}pájaro\hspace{1em}gato
# ciervo\hspace{1em}perro\hspace{1em}rana\hspace{1em}caballo\hspace{1em}
# Embarcacion\hspace{1em}camión$

# %% [markdown]
# #### **A:** Funciones, para seleccionar solo las clases: Gato y perro

# %%
def obtener_solo_imagenes_Etiqueta(imagen,etiqueta,num_etiqueta):
  Gatos_label=np.where(etiqueta== num_etiqueta)
  A=np.zeros([len(Gatos_label[0]),32,32,3],dtype=np.uint8)
  for c,i in enumerate(Gatos_label[0]): 
    A[c]=imagen[i]
  return A

def cambiar_scala_224x224(imagen):
  matriz_imagen1=np.zeros([len(imagen),224,224,3],dtype=np.uint8)
  for i in range(len(imagen)):
    img=imagen[i]
    scale_percent = 700 # percent of original size
    width = int(img.shape[1] * scale_percent / 100)
    height = int(img.shape[0] * scale_percent / 100)
    dim = (width, height)
    resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
    matriz_imagen1[i]=resized
  return matriz_imagen1

# %% [markdown]
# #### **B:** Descargar de keras datasets CIFAR10 y seleccionar las imagenes de las clases gato y perro del conjunto de **Train** y **Test**

# %%
#IMPORTAMOS EL CONJUNTO DE DATOS DE CIFAR10 DONE: Xdata[0][0]-->Train   Xdata[1][0]-->Test  Xdata[0][1]-->Ytrain  Xdata[1][1]-->Ytest
import tensorflow as tf
from keras.datasets import cifar10

Xdata = tf.keras.datasets.cifar10.load_data()
Xdata[1][0].shape
# Out:
# (10000, 32, 32, 3)

# %%
#OBTENEMOS SOLO LAS IMAGENES DE GATO=3 y perro=5 DE TEST DE CIFAR10, SON 1000 IMAGENES DE GATO y 1000 IMAGENES DE PERRO
gato_test = obtener_solo_imagenes_Etiqueta(Xdata[1][0],Xdata[1][1],num_etiqueta=3)
perro_test = obtener_solo_imagenes_Etiqueta(Xdata[1][0],Xdata[1][1],num_etiqueta=5)

#OBTENEMOS SOLO LAS IMAGENES DE GATO=3 y perro=5 DE TRAIN DE CIFAR10, SON 5000 IMAGENES DE GATO y 5000 IMAGENES DE PERRO
gato_train = obtener_solo_imagenes_Etiqueta(Xdata[0][0],Xdata[0][1],num_etiqueta=3)
perro_train = obtener_solo_imagenes_Etiqueta(Xdata[0][0],Xdata[0][1],num_etiqueta=5)

plt.imshow(gato_test[999])
plt.show()

# %% [markdown]
# ## **5. Agrupar conjunto de datos, en uno solo (X)**
#
# Gato_test, Conjunto de satos de 1000 imágenes tomadas de CIFAR10 - TEST
# Gato_train, Conjunto de satos de 5000 imágenes tomadas de CIFAR10 - TRAIN
#
# perro_test, Conjunto de satos de 1000 imágenes tomadas de CIFAR10 - TEST
# perro_train, Conjunto de satos de 5000 imágenes tomadas de CIFAR10 - TRAIN
#
#
# > $X= Cifar10_{gato} + Cifar10_{perro}$

# %% [markdown]
# ####**A:** Unir etiquetas y matrices de cada conjunto para fromar **X** de 2000 imágenes

# %%
#UNIR LAS IMAGENES EN UN SOLO CONJUNTO
#X = np.concatenate((gato_test[0:500], gato_train[0:500], perro_test[0:500], perro_train[0:500]), axis=0)
#X_label=np.concatenate(([1]*500, [1]*500, [0]*500, [0]*500), axis=0)
#UNIR ETIQUETAS EN UN SOLO CONJUNTO 
# 1-->GATO   0-->PERRO

Xtrain = np.concatenate((gato_train[0:800], perro_train[0:800]), axis=0)
Xtrain_label=np.concatenate(([1]*800,[0]*800), axis=0)
Xtest  = np.concatenate((gato_test[0:200], perro_test[0:200]), axis=0)
Xtest_label=np.concatenate(([1]*200,[0]*200), axis=0)

print(len(Xtrain),len(Xtrain_label),'  y  ',len(Xtest),len(Xtest_label))
# Out:
# 1600 1600   y   400 400

# %% [markdown]
# #### **B:** Cambiar tamaño de 32x32x3, a scala de: 224x224x3 (**Ver función:** cambiar_scala_224x224(X))

# %%
import cv2
Xtrain=cambiar_scala_224x224(Xtrain)
Xtest=cambiar_scala_224x224(Xtest)
print(Xtrain.shape,'  ',Xtest.shape)
# Out:
# (1600, 224, 224, 3)    (400, 224, 224, 3)

# %%
plt.imshow(Xtrain[5])
plt.title('clase:%s'%Xtrain_label[5])
plt.show()

# %% [markdown]
# ####**C:** Pasar X, a un pandas, en este caso por cuestiones de espacio en memoria, solo se cojen: X[i][0][0][0:3] y se agrega para cada imagen al pandas X_PD con sus respectivas etiquetas X_label.

# %%
#ARMAR PANDAS CON SOLO 5 DATOS DE CADA UNA DE LAS 12000 IMAGENES PARA PODER PARTICIONAR EL CONJUNTO Y PODER SACAR YTRAIN Y YTEST
Xtrain_PD=np.zeros([len(Xtrain),3])
Xtest_PD=np.zeros([len(Xtest),3])

for i in range(len(Xtrain)):
  Xtrain_PD[i]=Xtrain[i][0][0][0:3]

for i in range(len(Xtest)):
  Xtest_PD[i]=Xtest[i][0][0][0:3]

# %%
#ARMAR PANDAS DE TODAS LAS IMAGENNES, SE BARAJAN Y SE DEJAN LOS INDICES SIN REINICIAR, PARA LUEGO ENCONTRAR LA IMAGEN QUE LE PERTENECE A CADA ETIQUETA.
Xtrain_PD=pd.DataFrame(Xtrain_PD)
Xtrain_PD["label"]=Xtrain_label    
Xtrain_PD = Xtrain_PD.sample(frac=1)#.reset_index(drop=True) #frac=1significa devolver todas las filas (en orden aleatorio).

Xtest_PD=pd.DataFrame(Xtest_PD)
Xtest_PD["label"]=Xtest_label    
Xtest_PD = Xtest_PD.sample(frac=1)

# %% [markdown]
# ####**C:** Se particiona el conjuto de X_PD en Xtrain y Xtest, con 80%, 20% respectivamente y se sacan los Ytrain, Ytest por aparte.

# %%
#PARTICIONAR EL CONJUNTO DE XDATA EN XTRAIN Y XTEST
#from sklearn.model_selection import train_test_split
#Xtrain, Xtest = train_test_split(X_PD,test_size=0.2)

col_sal="label"
Ytrain = Xtrain_PD[col_sal]
Xtrain_PD.drop(columns=col_sal,inplace=True)
Ytest = Xtest_PD[col_sal]
Xtest_PD.drop(columns=col_sal,inplace=True)

print(len(Ytrain),len(Ytest))
# Out:
# 1600 400

# %% [markdown]
# ####**D:** Del pandas **X_PD** creado, se saca Ytrain, luego aquí,se sacan sus indices y se relacionan con la matrix de datos unidos **X** para armar el array **XTRAIN** que es el que va a la entrada de la red neuronal VGG-16.

# %%
#SE ARMA EL CONJUNTO XTRAIN FINAL, A PARTIR DE LOS INDICES DE LAS ETIQUETAS.

def relacion_indices_etiquetas_con_XTRAIN(X,Y):
  A=np.zeros([len(Y),224,224,3],dtype=np.uint8)
  B=[]
  for c,i in enumerate(Y.index):
    A[c]=X[i]
    B.append(Y[i])
  return A,np.array(B)


XTRAIN,YTRAIN = relacion_indices_etiquetas_con_XTRAIN(Xtrain,Ytrain)
XTEST,YTEST = relacion_indices_etiquetas_con_XTRAIN(Xtest,Ytest)
print('xtrain: ',XTRAIN.shape,YTRAIN.shape,'  xtest: ',XTEST.shape,YTEST.shape)

#c = np.all(np.array(YTRAIN) == np.array(Ytrain))
#Ytrain.index
# Out:
# xtrain:  (1600, 224, 224, 3) (1600,)   xtest:  (400, 224, 224, 3) (400,)

# %%
#LAS PASAMOS A TENSOR, NO HAYNECESIDAD DE QUE YTRAIN SEA UN TENSOR.
XTRAIN=tf.constant(XTRAIN)
YTRAIN=tf.constant(YTRAIN)

XTEST=tf.constant(XTEST)
YTEST=tf.constant(YTEST)
print(type(XTRAIN))
# Out:
# <class 'tensorflow.python.framework.ops.EagerTensor'>

# %%
plt.imshow(XTRAIN[5])
plt.title('clase:%s'%YTRAIN[5])
plt.show()

# %% [markdown]
# ##**6. Importar el modelo de la VGG-16 y configurar el último bloque.**
#
# ### Dejar la ultima capa y agregar la capa densa de salida, para que tenga 1 salida.

# %%
import tensorflow as tf

model_VGG16 = tf.keras.applications.vgg16.VGG16(weights='imagenet')#,include_top=False)
model_VGG16 = tf.keras.models.Model(inputs=model_VGG16.input, outputs=model_VGG16.layers[-3].output)

#X  =  tf.keras.layers.Dropout(0.2)(model_VGG16.output)
X  =  tf.keras.layers.Dense(4096,activation='relu',name='fc2' )(model_VGG16.output)
X1  =  tf.keras.layers.Dense(4096,activation='relu',name='fc2-3' )(X)
X3=tf.keras.layers.dot([X1, X], axes=1, normalize=True)#PROBAR CON TRUE
#X  =  tf.keras.layers.Dropout(0.2)(X)
output = tf.keras.layers.Dense(1, activation="sigmoid", name='salida')(X3)
model = tf.keras.models.Model(inputs=model_VGG16.input, outputs=output)


model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 224, 224, 64) 1792        input_2[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 224, 224, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 112, 112, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 112, 112, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 112, 112, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 56, 56, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 56, 56, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 28, 28, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 28, 28, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 14, 14, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 14, 14, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 7, 7, 512)    0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 25088)        0           block5_pool[0][0]
# __________________________________________________________________________________________________
# fc1 (Dense)                     (None, 4096)         102764544   flatten[0][0]
# __________________________________________________________________________________________________
# fc2 (Dense)                     (None, 4096)         16781312    fc1[0][0]
# __________________________________________________________________________________________________
# fc2-3 (Dense)                   (None, 4096)         16781312    fc2[0][0]
# __________________________________________________________________________________________________
# dot (Dot)                       (None, 1)            0           fc2-3[0][0]
#                                                                  fc2[0][0]
# __________________________________________________________________________________________________
# salida (Dense)                  (None, 1)            2           dot[0][0]
# ==================================================================================================
# Total params: 151,041,858
# Trainable params: 151,041,858
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#SE CONGELAN LOS PESOS DE TODAS LAS CAPAS MENOS DE LAS cuatro ULTIMAS CAPAS
for layer in model.layers[:-5]:
  layer.trainable=False

# %%
#SE VERIFICA QUE LAS CUATRO ULTIMAS CAPAS ESTE EN TRUE Y LAS DEMÁS EN FALSE
for layer in model.layers:
  layer, layer.trainable
  print(layer, layer.trainable)
# Out:
# <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f6a86595e48> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a865e96a0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a86544710> False
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f6a86563860> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a86544b70> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b0e346e48> False
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f6a86572ac8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a8656abe0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a86544ac8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a86576eb8> False
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f6a86506128> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a8657bda0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a86563320> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a8650bd30> False
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f6a8651b2e8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a86513f60> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b0f7ecbe0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a86523d68> False
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f6a86530400> False
# <tensorflow.python.keras.layers.core.Flatten object at 0x7f6a86538e10> False
# <tensorflow.python.keras.layers.core.Dense object at 0x7f6a86538dd8> True
# <tensorflow.python.keras.layers.core.Dense object at 0x7f6a864d5518> True
# <tensorflow.python.keras.layers.core.Dense object at 0x7f6a864d5a20> True
# <tensorflow.python.keras.layers.merge.Dot object at 0x7f6a864d59b0> True
# <tensorflow.python.keras.layers.core.Dense object at 0x7f6a864eeac8> True

# %% [markdown]
# ##**6. Definir el optimizador para la funcion de costo, así como la funcion de pérdida y las metricas de evaluación del odelo a través de la compilacion del modelo.**
#
# Loss $\hspace{1em} \rightarrow \hspace{1em}$ $-ylog(x)\hat{y} + (1-y)log(1-\hat{y}) $

# %%
#DEFINIR OPTIMIZADOR, FUNCIONES DE PERIDA Y METRICAS
#optimizer = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)#, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
#loss='mean_squared_logariic_errorthm'
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['mse','mae','accuracy','Recall','Precision'])#,

# %% [markdown]
# ##**7. Entrenar el modelo con XTRAIN como un array de 4 dimensiones.**
#
# ---

# %%
print(len(XTRAIN),len(YTRAIN))
# Out:
# 1600 1600

# %%
#ENTRENAR EL MODELO CREADO 
history=model.fit(XTRAIN,YTRAIN,epochs=250,batch_size=64)
# Out:
# Epoch 1/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.6920 - mse: 0.2494 - mae: 0.4989 - accuracy: 0.5088 - recall: 0.0200 - precision: 0.8889
# Epoch 2/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.6458 - mse: 0.2274 - mae: 0.4578 - accuracy: 0.6681 - recall: 0.5350 - precision: 0.7291
# Epoch 3/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.5974 - mse: 0.2050 - mae: 0.4298 - accuracy: 0.7856 - recall: 0.7487 - precision: 0.8084
# Epoch 4/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.5621 - mse: 0.1891 - mae: 0.4106 - accuracy: 0.8350 - recall: 0.8388 - precision: 0.8325
# Epoch 5/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.5275 - mse: 0.1734 - mae: 0.3911 - accuracy: 0.8737 - recall: 0.8988 - precision: 0.8560
# Epoch 6/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.5125 - mse: 0.1665 - mae: 0.3841 - accuracy: 0.8888 - recall: 0.9187 - precision: 0.8667
# Epoch 7/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.5000 - mse: 0.1606 - mae: 0.3763 - accuracy: 0.9069 - recall: 0.9262 - precision: 0.8917
# Epoch 8/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.4847 - mse: 0.1536 - mae: 0.3687 - accuracy: 0.9194 - recall: 0.9513 - precision: 0.8942
# Epoch 9/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.4813 - mse: 0.1519 - mae: 0.3658 - accuracy: 0.9187 - recall: 0.9438 - precision: 0.8988
# Epoch 10/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.4721 - mse: 0.1476 - mae: 0.3609 - accuracy: 0.9237 - recall: 0.9500 - precision: 0.9026
# Epoch 11/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.4599 - mse: 0.1420 - mae: 0.3538 - accuracy: 0.9369 - recall: 0.9600 - precision: 0.9176
# Epoch 12/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.4612 - mse: 0.1425 - mae: 0.3540 - accuracy: 0.9300 - recall: 0.9538 - precision: 0.9105
# Epoch 13/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.4509 - mse: 0.1378 - mae: 0.3486 - accuracy: 0.9337 - recall: 0.9563 - precision: 0.9151
# Epoch 14/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.4467 - mse: 0.1358 - mae: 0.3460 - accuracy: 0.9356 - recall: 0.9650 - precision: 0.9115
# Epoch 15/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.4348 - mse: 0.1303 - mae: 0.3389 - accuracy: 0.9463 - recall: 0.9688 - precision: 0.9270
# Epoch 16/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.4268 - mse: 0.1266 - mae: 0.3345 - accuracy: 0.9494 - recall: 0.9725 - precision: 0.9295
# Epoch 17/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.4219 - mse: 0.1244 - mae: 0.3312 - accuracy: 0.9500 - recall: 0.9725 - precision: 0.9306
# Epoch 18/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.4273 - mse: 0.1268 - mae: 0.3340 - accuracy: 0.9362 - recall: 0.9675 - precision: 0.9106
# Epoch 19/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.4138 - mse: 0.1206 - mae: 0.3266 - accuracy: 0.9494 - recall: 0.9762 - precision: 0.9265
# Epoch 20/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.4072 - mse: 0.1177 - mae: 0.3225 - accuracy: 0.9525 - recall: 0.9775 - precision: 0.9310
# Epoch 21/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.4129 - mse: 0.1202 - mae: 0.3247 - accuracy: 0.9419 - recall: 0.9650 - precision: 0.9223
# Epoch 22/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.4015 - mse: 0.1150 - mae: 0.3183 - accuracy: 0.9519 - recall: 0.9750 - precision: 0.9319
# Epoch 23/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.3924 - mse: 0.1110 - mae: 0.3126 - accuracy: 0.9569 - recall: 0.9787 - precision: 0.9377
# Epoch 24/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.3878 - mse: 0.1089 - mae: 0.3100 - accuracy: 0.9575 - recall: 0.9812 - precision: 0.9368
# Epoch 25/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.3805 - mse: 0.1057 - mae: 0.3055 - accuracy: 0.9613 - recall: 0.9862 - precision: 0.9393
# Epoch 26/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.3801 - mse: 0.1056 - mae: 0.3047 - accuracy: 0.9569 - recall: 0.9787 - precision: 0.9377
# Epoch 27/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.3755 - mse: 0.1035 - mae: 0.3023 - accuracy: 0.9581 - recall: 0.9862 - precision: 0.9337
# Epoch 28/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.3713 - mse: 0.1017 - mae: 0.2989 - accuracy: 0.9588 - recall: 0.9825 - precision: 0.9379
# Epoch 29/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.3741 - mse: 0.1029 - mae: 0.3003 - accuracy: 0.9531 - recall: 0.9837 - precision: 0.9270
# Epoch 30/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.3729 - mse: 0.1024 - mae: 0.2991 - accuracy: 0.9513 - recall: 0.9762 - precision: 0.9298
# Epoch 31/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.3586 - mse: 0.0962 - mae: 0.2906 - accuracy: 0.9613 - recall: 0.9875 - precision: 0.9382
# Epoch 32/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.3545 - mse: 0.0944 - mae: 0.2875 - accuracy: 0.9625 - recall: 0.9875 - precision: 0.9405
# Epoch 33/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.3551 - mse: 0.0948 - mae: 0.2871 - accuracy: 0.9588 - recall: 0.9800 - precision: 0.9400
# Epoch 34/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.3575 - mse: 0.0960 - mae: 0.2882 - accuracy: 0.9525 - recall: 0.9787 - precision: 0.9299
# Epoch 35/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.3441 - mse: 0.0900 - mae: 0.2804 - accuracy: 0.9631 - recall: 0.9887 - precision: 0.9405
# Epoch 36/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.3378 - mse: 0.0874 - mae: 0.2763 - accuracy: 0.9663 - recall: 0.9912 - precision: 0.9440
# Epoch 37/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.3350 - mse: 0.0862 - mae: 0.2741 - accuracy: 0.9663 - recall: 0.9900 - precision: 0.9451
# Epoch 38/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.3318 - mse: 0.0849 - mae: 0.2718 - accuracy: 0.9663 - recall: 0.9900 - precision: 0.9451
# Epoch 39/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.3334 - mse: 0.0856 - mae: 0.2716 - accuracy: 0.9625 - recall: 0.9837 - precision: 0.9436
# Epoch 40/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.3247 - mse: 0.0819 - mae: 0.2668 - accuracy: 0.9675 - recall: 0.9900 - precision: 0.9474
# Epoch 41/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.3205 - mse: 0.0802 - mae: 0.2640 - accuracy: 0.9688 - recall: 0.9912 - precision: 0.9486
# Epoch 42/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.3164 - mse: 0.0785 - mae: 0.2613 - accuracy: 0.9694 - recall: 0.9925 - precision: 0.9486
# Epoch 43/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.3133 - mse: 0.0773 - mae: 0.2589 - accuracy: 0.9700 - recall: 0.9937 - precision: 0.9487
# Epoch 44/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.3105 - mse: 0.0762 - mae: 0.2567 - accuracy: 0.9700 - recall: 0.9937 - precision: 0.9487
# Epoch 45/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.3077 - mse: 0.0752 - mae: 0.2546 - accuracy: 0.9700 - recall: 0.9937 - precision: 0.9487
# Epoch 46/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.3051 - mse: 0.0741 - mae: 0.2525 - accuracy: 0.9700 - recall: 0.9937 - precision: 0.9487
# Epoch 47/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.3024 - mse: 0.0731 - mae: 0.2504 - accuracy: 0.9700 - recall: 0.9937 - precision: 0.9487
# Epoch 48/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.2999 - mse: 0.0722 - mae: 0.2484 - accuracy: 0.9700 - recall: 0.9937 - precision: 0.9487
# Epoch 49/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.2974 - mse: 0.0712 - mae: 0.2464 - accuracy: 0.9700 - recall: 0.9937 - precision: 0.9487
# Epoch 50/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.2949 - mse: 0.0703 - mae: 0.2444 - accuracy: 0.9700 - recall: 0.9937 - precision: 0.9487
# Epoch 51/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2924 - mse: 0.0694 - mae: 0.2425 - accuracy: 0.9700 - recall: 0.9937 - precision: 0.9487
# Epoch 52/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2900 - mse: 0.0685 - mae: 0.2405 - accuracy: 0.9700 - recall: 0.9937 - precision: 0.9487
# Epoch 53/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.2877 - mse: 0.0676 - mae: 0.2386 - accuracy: 0.9700 - recall: 0.9937 - precision: 0.9487
# Epoch 54/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.2854 - mse: 0.0668 - mae: 0.2367 - accuracy: 0.9700 - recall: 0.9937 - precision: 0.9487
# Epoch 55/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2831 - mse: 0.0660 - mae: 0.2349 - accuracy: 0.9700 - recall: 0.9937 - precision: 0.9487
# Epoch 56/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.2809 - mse: 0.0652 - mae: 0.2330 - accuracy: 0.9700 - recall: 0.9937 - precision: 0.9487
# Epoch 57/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.2787 - mse: 0.0644 - mae: 0.2312 - accuracy: 0.9700 - recall: 0.9937 - precision: 0.9487
# Epoch 58/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2765 - mse: 0.0636 - mae: 0.2294 - accuracy: 0.9700 - recall: 0.9937 - precision: 0.9487
# Epoch 59/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.2744 - mse: 0.0629 - mae: 0.2277 - accuracy: 0.9700 - recall: 0.9937 - precision: 0.9487
# Epoch 60/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2722 - mse: 0.0621 - mae: 0.2259 - accuracy: 0.9700 - recall: 0.9937 - precision: 0.9487
# Epoch 61/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.2696 - mse: 0.0612 - mae: 0.2240 - accuracy: 0.9700 - recall: 0.9937 - precision: 0.9487
# Epoch 62/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2673 - mse: 0.0604 - mae: 0.2221 - accuracy: 0.9706 - recall: 0.9950 - precision: 0.9487
# Epoch 63/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.2653 - mse: 0.0597 - mae: 0.2204 - accuracy: 0.9706 - recall: 0.9950 - precision: 0.9487
# Epoch 64/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2633 - mse: 0.0590 - mae: 0.2187 - accuracy: 0.9706 - recall: 0.9950 - precision: 0.9487
# Epoch 65/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2614 - mse: 0.0584 - mae: 0.2171 - accuracy: 0.9706 - recall: 0.9950 - precision: 0.9487
# Epoch 66/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2594 - mse: 0.0577 - mae: 0.2155 - accuracy: 0.9706 - recall: 0.9950 - precision: 0.9487
# Epoch 67/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.2575 - mse: 0.0571 - mae: 0.2138 - accuracy: 0.9706 - recall: 0.9950 - precision: 0.9487
# Epoch 68/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2552 - mse: 0.0563 - mae: 0.2122 - accuracy: 0.9706 - recall: 0.9950 - precision: 0.9487
# Epoch 69/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2530 - mse: 0.0556 - mae: 0.2103 - accuracy: 0.9712 - recall: 0.9962 - precision: 0.9488
# Epoch 70/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2511 - mse: 0.0549 - mae: 0.2087 - accuracy: 0.9712 - recall: 0.9962 - precision: 0.9488
# Epoch 71/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2493 - mse: 0.0544 - mae: 0.2072 - accuracy: 0.9712 - recall: 0.9962 - precision: 0.9488
# Epoch 72/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.2475 - mse: 0.0538 - mae: 0.2056 - accuracy: 0.9712 - recall: 0.9962 - precision: 0.9488
# Epoch 73/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.2457 - mse: 0.0532 - mae: 0.2041 - accuracy: 0.9712 - recall: 0.9962 - precision: 0.9488
# Epoch 74/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2436 - mse: 0.0526 - mae: 0.2025 - accuracy: 0.9712 - recall: 0.9962 - precision: 0.9488
# Epoch 75/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2415 - mse: 0.0518 - mae: 0.2010 - accuracy: 0.9719 - recall: 0.9975 - precision: 0.9489
# Epoch 76/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2394 - mse: 0.0512 - mae: 0.1995 - accuracy: 0.9719 - recall: 0.9975 - precision: 0.9489
# Epoch 77/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2366 - mse: 0.0502 - mae: 0.1974 - accuracy: 0.9725 - recall: 0.9987 - precision: 0.9489
# Epoch 78/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2345 - mse: 0.0495 - mae: 0.1957 - accuracy: 0.9731 - recall: 1.0000 - precision: 0.9490
# Epoch 79/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2328 - mse: 0.0490 - mae: 0.1942 - accuracy: 0.9731 - recall: 1.0000 - precision: 0.9490
# Epoch 80/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.2311 - mse: 0.0485 - mae: 0.1927 - accuracy: 0.9731 - recall: 1.0000 - precision: 0.9490
# Epoch 81/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2389 - mse: 0.0516 - mae: 0.1975 - accuracy: 0.9681 - recall: 0.9962 - precision: 0.9432
# Epoch 82/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2543 - mse: 0.0583 - mae: 0.2053 - accuracy: 0.9544 - recall: 0.9775 - precision: 0.9343
# Epoch 83/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2307 - mse: 0.0485 - mae: 0.1916 - accuracy: 0.9725 - recall: 0.9962 - precision: 0.9511
# Epoch 84/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2244 - mse: 0.0463 - mae: 0.1880 - accuracy: 0.9737 - recall: 0.9962 - precision: 0.9533
# Epoch 85/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2251 - mse: 0.0468 - mae: 0.1876 - accuracy: 0.9725 - recall: 0.9925 - precision: 0.9543
# Epoch 86/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2258 - mse: 0.0471 - mae: 0.1879 - accuracy: 0.9706 - recall: 0.9925 - precision: 0.9509
# Epoch 87/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2183 - mse: 0.0440 - mae: 0.1841 - accuracy: 0.9756 - recall: 0.9925 - precision: 0.9601
# Epoch 88/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2083 - mse: 0.0402 - mae: 0.1777 - accuracy: 0.9812 - recall: 0.9975 - precision: 0.9661
# Epoch 89/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2063 - mse: 0.0396 - mae: 0.1760 - accuracy: 0.9812 - recall: 0.9962 - precision: 0.9672
# Epoch 90/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.2147 - mse: 0.0430 - mae: 0.1809 - accuracy: 0.9756 - recall: 0.9912 - precision: 0.9612
# Epoch 91/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.2062 - mse: 0.0399 - mae: 0.1748 - accuracy: 0.9794 - recall: 0.9950 - precision: 0.9648
# Epoch 92/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0
- accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 216/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0964 - mse: 0.0156 - mae: 0.0720 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 217/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0961 - mse: 0.0155 - mae: 0.0715 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 218/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0957 - mse: 0.0155 - mae: 0.0711 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 219/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.0954 - mse: 0.0155 - mae: 0.0707 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 220/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.0950 - mse: 0.0154 - mae: 0.0704 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 221/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.0947 - mse: 0.0154 - mae: 0.0699 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 222/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.0944 - mse: 0.0153 - mae: 0.0696 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 223/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0940 - mse: 0.0153 - mae: 0.0692 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 224/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0937 - mse: 0.0153 - mae: 0.0688 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 225/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0934 - mse: 0.0152 - mae: 0.0684 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 226/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0930 - mse: 0.0152 - mae: 0.0680 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 227/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0927 - mse: 0.0152 - mae: 0.0677 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 228/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0924 - mse: 0.0151 - mae: 0.0673 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 229/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.0921 - mse: 0.0151 - mae: 0.0669 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 230/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.0918 - mse: 0.0151 - mae: 0.0666 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 231/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0915 - mse: 0.0151 - mae: 0.0662 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 232/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.0912 - mse: 0.0150 - mae: 0.0659 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 233/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0909 - mse: 0.0150 - mae: 0.0655 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 234/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.0906 - mse: 0.0150 - mae: 0.0652 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 235/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0903 - mse: 0.0149 - mae: 0.0648 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 236/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0900 - mse: 0.0149 - mae: 0.0645 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 237/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0897 - mse: 0.0149 - mae: 0.0641 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 238/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0894 - mse: 0.0149 - mae: 0.0638 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 239/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0891 - mse: 0.0148 - mae: 0.0635 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 240/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0889 - mse: 0.0148 - mae: 0.0632 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 241/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.0886 - mse: 0.0148 - mae: 0.0628 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 242/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0883 - mse: 0.0148 - mae: 0.0625 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 243/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0880 - mse: 0.0147 - mae: 0.0622 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 244/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0878 - mse: 0.0147 - mae: 0.0619 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 245/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0875 - mse: 0.0147 - mae: 0.0615 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 246/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0872 - mse: 0.0147 - mae: 0.0613 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 247/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0870 - mse: 0.0146 - mae: 0.0609 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 248/250
# 25/25 [==============================] - 4s 153ms/step - loss: 0.0867 - mse: 0.0146 - mae: 0.0606 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 249/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0865 - mse: 0.0146 - mae: 0.0603 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732
# Epoch 250/250
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0862 - mse: 0.0146 - mae: 0.0600 - accuracy: 0.9862 - recall: 1.0000 - precision: 0.9732

# %% [markdown]
# ##**8. Generar gráfica de: loss(pérdida) y accuracy(acierto) en cada época realizada.**

# %%
import pandas as pd

pd.DataFrame(history.history).plot(figsize=(8, 6))
plt.grid(True)
plt.gca().set_ylim(0, 1)

plt.show()

# %% [markdown]
# ##**9. Predecir con el modelo, la clasificación de cada imagen del conjunto de Test**

# %%
#SE EVALÚA EL MODELO

Valores=(model.predict(XTEST))
#Valores

# %%
#Valores_label=np.argmax(Valores, axis=1)
#Valores_label
Valores_label=np.around(Valores)
Valores_label.shape
# Out:
# (400, 1)

# %% [markdown]
# ##**10. Sacar métricas de evaluación, para mirar el rendimiento del modelo.**

# %% [markdown]
# > **A. Matriz de confusión simple.**

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

#YTEST=YTEST.reshape(len(Ytest),1)

acc = accuracy_score(YTEST,Valores_label)
print('acierto: ',acc)
cm=confusion_matrix(YTEST,Valores_label)
cm
# Out:
# acierto:  0.74
# array([[162,  38],
#        [ 66, 134]])

# %% [markdown]
# >**B. Matriz de confusión, con porcentjes de acierto.**

# %%
from sklearn.utils.multiclass import unique_labels


def plot_confusion_matrix(matrix,Ytest,Valores_label,acc,Valores2):
    fig = plt.figure(figsize=(5,5))
    ax = fig.add_subplot(111)
    cmap=plt.cm.Blues
    matrix = 100*matrix.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    cax = ax.matshow(matrix, interpolation='nearest', cmap=cmap)
    fig.colorbar(cax)
    classes = unique_labels(Ytest,Valores_label)
    classes1= Valores2
    ax.set(xticks=np.arange(matrix.shape[1]),
           yticks=np.arange(matrix.shape[0]),
           xticklabels=classes1, yticklabels=classes1,
           title='ACC = %.1f %%' % (100*acc),
           ylabel='True label',
           xlabel='Predicted label')
    fmt = '.1f'
    thresh = matrix.max() / 2.
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(j, i, format(matrix[i, j], fmt),
                    ha="center", va="center",
                    color="black",fontsize=12)
    fig.tight_layout()

#Valores_label_texto=convertir_salida_texto(Valores_label)
plot_confusion_matrix(cm,YTEST,Valores_label,acc,Valores2=["Perro","Gato"])

# %% [markdown]
# > **C. Reporte de algunas métricas: Precisión, recall, F1 y Support, para el umbral de clasificación 0,5(por defecto usado por keras).**

# %%
from sklearn.metrics import classification_report

target_names = ['Perro','Gato']
cr=classification_report(YTEST, Valores_label,labels=range(len(target_names)),target_names=target_names)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#        Perro       0.71      0.81      0.76       200
#         Gato       0.78      0.67      0.72       200
#
#     accuracy                           0.74       400
#    macro avg       0.74      0.74      0.74       400
# weighted avg       0.74      0.74      0.74       400

# %% [markdown]
# >**D. Curva ROC, para cada clase, variando los umbrales de decisión(Thresold) o, en este caso con la probabilidad de que pertenezca a una de las salidas.**

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc



Ytest_Bin= label_binarize(YTEST, classes=[0,1])
Valores_Bin= label_binarize(Valores_label, classes=[0,1])
roc_auc, fpr, tpr, n_classes = roc_multiclass(Ytest_Bin,Valores_Bin,colum=1)
roc_auc_mc(roc_auc,fpr,tpr,n_classes,'ROC curve ')

# %%
#GRAFICAR LAS PRIMERAS 10 IMAGENES
tam=10
index=0
plt.figure(figsize=(tam*2, 12))
for i in range(1,tam):
  index += 1
  plt.subplot((tam//10), 10, index)
  plt.imshow(XTEST[i-1])
  plt.title("Class: {}".format(Valores_label[i-1]))
  plt.axis("off")
plt.show()
