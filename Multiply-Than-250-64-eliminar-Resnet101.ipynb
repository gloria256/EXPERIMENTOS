# %% [markdown]
# <a href="https://colab.research.google.com/github/gloria256/EXPERIMENTOS/blob/master/Multiply-Than-250-64-eliminar-Resnet101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CLASIFICADOR BINARIO USANDO LA RED: RESNET101**

# %% [markdown]
# ## **1. Librerías necesarias y descarga de la función para graficar la curva ROC.**

# %%
#IMPORTACION DE LIBRERIAS NECESARIAS
import pandas as pd
import tensorflow_datasets as tfds
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os
from keras.applications.resnet import preprocess_input, decode_predictions
import sklearn

# ACCESO A GOOGLE DRIVE
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#ARCHIVO DE FUNCIONES
file_id = '1QTJIzZb4xL9_it6AF4qpz6KJGIpprIVD' 
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('funciones_people.py') 
from funciones_people import roc_multiclass, roc_auc_mc
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## **4. Descargar imágenes de CIFAR-10**
#
# consta de 60000 imágenes en color de 32x32 en 10 clases, con 6000 imágenes por clase. Hay 50000 imágenes de entrenamiento y 10000 imágenes de prueba.
#
# El conjunto de datos se divide en cinco lotes de entrenamiento y un lote de prueba, cada uno con 10000 imágenes. El lote de prueba contiene exactamente 1000 imágenes seleccionadas al azar de cada clase.
#
# $avión\hspace{1em}automóvil\hspace{1em}pájaro\hspace{1em}gato
# ciervo\hspace{1em}perro\hspace{1em}rana\hspace{1em}caballo\hspace{1em}
# Embarcacion\hspace{1em}camión$

# %% [markdown]
# #### **A:** Funciones, para seleccionar solo las clases: Gato y perro

# %%
def obtener_solo_imagenes_Etiqueta(imagen,etiqueta,num_etiqueta):
  Gatos_label=np.where(etiqueta== num_etiqueta)
  A=np.zeros([len(Gatos_label[0]),32,32,3],dtype=np.uint8)
  for c,i in enumerate(Gatos_label[0]): 
    A[c]=imagen[i]
  return A

def cambiar_scala_224x224(imagen):
  matriz_imagen1=np.zeros([len(imagen),224,224,3],dtype=np.uint8)
  for i in range(len(imagen)):
    img=imagen[i]
    scale_percent = 700 # percent of original size
    width = int(img.shape[1] * scale_percent / 100)
    height = int(img.shape[0] * scale_percent / 100)
    dim = (width, height)
    resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
    matriz_imagen1[i]=resized
  return matriz_imagen1

# %% [markdown]
# #### **B:** Descargar de keras datasets CIFAR10 y seleccionar las imagenes de las clases gato y perro del conjunto de **Train** y **Test**

# %%
#IMPORTAMOS EL CONJUNTO DE DATOS DE CIFAR10 DONE: Xdata[0][0]-->Train   Xdata[1][0]-->Test  Xdata[0][1]-->Ytrain  Xdata[1][1]-->Ytest
import tensorflow as tf
from keras.datasets import cifar10

Xdata = tf.keras.datasets.cifar10.load_data()
Xdata[1][0].shape
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# (10000, 32, 32, 3)

# %%
#OBTENEMOS SOLO LAS IMAGENES DE GATO=3 y perro=5 DE TEST DE CIFAR10, SON 1000 IMAGENES DE GATO y 1000 IMAGENES DE PERRO
gato_test = obtener_solo_imagenes_Etiqueta(Xdata[1][0],Xdata[1][1],num_etiqueta=3)
perro_test = obtener_solo_imagenes_Etiqueta(Xdata[1][0],Xdata[1][1],num_etiqueta=5)

#OBTENEMOS SOLO LAS IMAGENES DE GATO=3 y perro=5 DE TRAIN DE CIFAR10, SON 5000 IMAGENES DE GATO y 5000 IMAGENES DE PERRO
gato_train = obtener_solo_imagenes_Etiqueta(Xdata[0][0],Xdata[0][1],num_etiqueta=3)
perro_train = obtener_solo_imagenes_Etiqueta(Xdata[0][0],Xdata[0][1],num_etiqueta=5)

plt.imshow(gato_test[999])
plt.show()

# %% [markdown]
# ## **5. Agrupar conjunto de datos, en uno solo (X)**
#
# Gato_test, Conjunto de satos de 1000 imágenes tomadas de CIFAR10 - TEST
# Gato_train, Conjunto de satos de 5000 imágenes tomadas de CIFAR10 - TRAIN
#
# perro_test, Conjunto de satos de 1000 imágenes tomadas de CIFAR10 - TEST
# perro_train, Conjunto de satos de 5000 imágenes tomadas de CIFAR10 - TRAIN
#
#
# > $X= Cifar10_{gato} + Cifar10_{perro}$

# %% [markdown]
# ####**A:** Unir etiquetas y matrices de cada conjunto para fromar **X** de 2000 imágenes

# %%
#UNIR LAS IMAGENES EN UN SOLO CONJUNTO
#X = np.concatenate((gato_test[0:500], gato_train[0:500], perro_test[0:500], perro_train[0:500]), axis=0)
#X_label=np.concatenate(([1]*500, [1]*500, [0]*500, [0]*500), axis=0)
#UNIR ETIQUETAS EN UN SOLO CONJUNTO 
# 1-->GATO   0-->PERRO

Xtrain = np.concatenate((gato_train[0:800], perro_train[0:800]), axis=0)
Xtrain_label=np.concatenate(([1]*800,[0]*800), axis=0)
Xtest  = np.concatenate((gato_test[0:200], perro_test[0:200]), axis=0)
Xtest_label=np.concatenate(([1]*200,[0]*200), axis=0)

print(len(Xtrain),len(Xtrain_label),'  y  ',len(Xtest),len(Xtest_label))
# Out:
# 1600 1600   y   400 400

# %% [markdown]
# #### **B:** Cambiar tamaño de 32x32x3, a scala de: 224x224x3 (**Ver función: cambiar_scala_224x224(X))**

# %%
import cv2
Xtrain=cambiar_scala_224x224(Xtrain)
Xtest=cambiar_scala_224x224(Xtest)
print(Xtrain.shape,'  ',Xtest.shape)
# Out:
# (1600, 224, 224, 3)    (400, 224, 224, 3)

# %%
plt.imshow(Xtrain[5])
plt.title('clase:%s'%Xtrain_label[5])
plt.show()

# %% [markdown]
# ####**C:** Pasar X, a un pandas, en este caso por cuestiones de espacio en memoria, solo se cojen: X[i][0][0][0:3] y se agrega para cada imagen al pandas X_PD con sus respectivas etiquetas X_label.

# %%
#ARMAR PANDAS CON SOLO 5 DATOS DE CADA UNA DE LAS 12000 IMAGENES PARA PODER PARTICIONAR EL CONJUNTO Y PODER SACAR YTRAIN Y YTEST
Xtrain_PD=np.zeros([len(Xtrain),3])
Xtest_PD=np.zeros([len(Xtest),3])

for i in range(len(Xtrain)):
  Xtrain_PD[i]=Xtrain[i][0][0][0:3]

for i in range(len(Xtest)):
  Xtest_PD[i]=Xtest[i][0][0][0:3]

# %%
#ARMAR PANDAS DE TODAS LAS IMAGENNES, SE BARAJAN Y SE DEJAN LOS INDICES SIN REINICIAR, PARA LUEGO ENCONTRAR LA IMAGEN QUE LE PERTENECE A CADA ETIQUETA.
Xtrain_PD=pd.DataFrame(Xtrain_PD)
Xtrain_PD["label"]=Xtrain_label    
Xtrain_PD = Xtrain_PD.sample(frac=1)#.reset_index(drop=True) #frac=1significa devolver todas las filas (en orden aleatorio).

Xtest_PD=pd.DataFrame(Xtest_PD)
Xtest_PD["label"]=Xtest_label    
Xtest_PD = Xtest_PD.sample(frac=1)

# %% [markdown]
# ####**C:** Se particiona el conjuto de X_PD en Xtrain y Xtest, con 80%, 20% respectivamente y se sacan los Ytrain, Ytest por aparte.

# %%
#PARTICIONAR EL CONJUNTO DE XDATA EN XTRAIN Y XTEST
#from sklearn.model_selection import train_test_split
#Xtrain, Xtest = train_test_split(X_PD,test_size=0.2)

col_sal="label"
Ytrain = Xtrain_PD[col_sal]
Xtrain_PD.drop(columns=col_sal,inplace=True)
Ytest = Xtest_PD[col_sal]
Xtest_PD.drop(columns=col_sal,inplace=True)

print(len(Ytrain),len(Ytest))
# Out:
# 1600 400

# %% [markdown]
# ####**D:** Del pandas **X_PD** creado, se saca Ytrain, luego aquí,se sacan sus indices y se relacionan con la matrix de datos unidos **X** para armar el array **XTRAIN** que es el que va a la entrada de la red neuronal VGG-16.

# %%
#SE ARMA EL CONJUNTO XTRAIN FINAL, A PARTIR DE LOS INDICES DE LAS ETIQUETAS.

def relacion_indices_etiquetas_con_XTRAIN(X,Y):
  A=np.zeros([len(Y),224,224,3],dtype=np.uint8)
  B=[]
  for c,i in enumerate(Y.index):
    A[c]=X[i]
    B.append(Y[i])
  return A,np.array(B)


XTRAIN,YTRAIN = relacion_indices_etiquetas_con_XTRAIN(Xtrain,Ytrain)
XTEST,YTEST = relacion_indices_etiquetas_con_XTRAIN(Xtest,Ytest)
print('xtrain: ',XTRAIN.shape,YTRAIN.shape,'  xtest: ',XTEST.shape,YTEST.shape)

#c = np.all(np.array(YTRAIN) == np.array(Ytrain))
#Ytrain.index
# Out:
# xtrain:  (1600, 224, 224, 3) (1600,)   xtest:  (400, 224, 224, 3) (400,)

# %%
#LAS PASAMOS A TENSOR, NO HAYNECESIDAD DE QUE YTRAIN SEA UN TENSOR.
XTRAIN=tf.constant(XTRAIN)
YTRAIN=tf.constant(YTRAIN)

XTEST=tf.constant(XTEST)
YTEST=tf.constant(YTEST)

print(type(XTRAIN))
# Out:
# <class 'tensorflow.python.framework.ops.EagerTensor'>

# %%
plt.imshow(XTRAIN[5])
plt.title('clase:%s'%YTRAIN[5])
plt.show()

# %% [markdown]
# ##**6. Importar el modelo de la ResNet101 y configurar el último bloque.**
#
#
# ### Dejar la ultima capa y agregar la capa densa de salida, para que tenga 1 salida.

# %%
#FUCIÓN DE CAPAS: https://stackoverflow.com/questions/52542275/merging-layers-on-keras-dot-product
import tensorflow as tf

model = tf.keras.applications.ResNet101(weights='imagenet',include_top=False)

#X= tf.keras.layers.GlobalMaxPool2D()(model.output)#GlobalAveragePooling2D()(model.output)
X= tf.keras.layers.GlobalAveragePooling2D()(model.output)#GlobalAveragePooling2D()(model.output)
X1 = tf.keras.layers.Dense(1000, activation="tanh", name='Dense0')(X) #,kernel_regularizer=tf.keras.regularizers.l2(0.01)
X2 = tf.keras.layers.Dense(1000, activation="tanh", name='Dense1')(X1)#,kernel_regularizer=tf.keras.regularizers.l2(0.01)
#X1 =  tf.keras.layers.Dropout(0.2)(X1)#(model.output)
X3=tf.keras.layers.dot([X2, X1], axes=1, normalize=True)#PROBAR CON TRUE
output = tf.keras.layers.Dense(1, activation="sigmoid", name='salida')(X3)
model = tf.keras.models.Model(inputs=model.input, outputs=output)

model.summary()
#tf.keras.utils.plot_model(model_GoogleNet,show_shapes=True, show_layer_names=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171450368/171446536 [==============================] - 1s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, None, None, 6 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, None, None, 6 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, None, None, 6 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, None, None, 6 0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, None, None, 6 4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, None, None, 6 256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, None, None, 6 0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, None, None, 6 36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, None, None, 6 256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, None, None, 6 0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, None, None, 2 16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, None, None, 2 1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, None, None, 2 1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, None, None, 2 0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, None, None, 2 0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, None, None, 6 16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, None, None, 6 256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, None, None, 6 0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, None, None, 6 36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, None, None, 6 256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, None, None, 6 0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, None, None, 2 1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, None, None, 2 0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, None, None, 2 0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, None, None, 6 16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, None, None, 6 256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, None, None, 6 0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, None, None, 6 36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, None, None, 6 256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, None, None, 6 0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, None, None, 2 1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, None, None, 2 0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, None, None, 2 0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, None, None, 1 32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, None, None, 1 512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, None, None, 1 0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, None, None, 1 147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, None, None, 1 512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, None, None, 1 0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, None, None, 5 131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, None, None, 5 2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, None, None, 5 2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, None, None, 5 0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, None, None, 5 0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, None, None, 1 65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, None, None, 1 512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, None, None, 1 0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, None, None, 1 147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, None, None, 1 512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, None, None, 1 0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, None, None, 5 2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, None, None, 5 0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, None, None, 5 0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, None, None, 1 65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, None, None, 1 512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, None, None, 1 0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, None, None, 1 147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, None, None, 1 512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, None, None, 1 0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, None, None, 5 2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, None, None, 5 0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, None, None, 5 0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, None, None, 1 65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, None, None, 1 512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, None, None, 1 0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, None, None, 1 147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, None, None, 1 512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, None, None, 1 0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, None, None, 5 2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, None, None, 5 0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, None, None, 5 0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, None, None, 2 131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, None, None, 2 0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, None, None, 2 0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, None, None, 1 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, None, None, 1 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, None, None, 1 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, None, None, 1 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, None, None, 2 0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, None, None, 2 0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, None, None, 1 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, None, None, 1 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, None, None, 2 0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, None, None, 2 0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, None, None, 1 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, None, None, 1 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, None, None, 2 0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, None, None, 2 0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, None, None, 1 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, None, None, 1 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, None, None, 2 0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, None, None, 2 0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, None, None, 1 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, None, None, 1 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, None, None, 2 0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, None, None, 2 0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, None, None, 1 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, None, None, 1 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, None, None, 2 0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_relu (Activation (None, None, None, 2 0           conv4_block7_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block7_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block7_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_add (Add)          (None, None, None, 1 0           conv4_block6_out[0][0]
#                                                                  conv4_block7_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_out (Activation)   (None, None, None, 1 0           conv4_block7_add[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block7_out[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, None, None, 2 0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_relu (Activation (None, None, None, 2 0           conv4_block8_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block8_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block8_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_add (Add)          (None, None, None, 1 0           conv4_block7_out[0][0]
#                                                                  conv4_block8_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_out (Activation)   (None, None, None, 1 0           conv4_block8_add[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block8_out[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, None, None, 2 0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_relu (Activation (None, None, None, 2 0           conv4_block9_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block9_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block9_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_add (Add)          (None, None, None, 1 0           conv4_block8_out[0][0]
#                                                                  conv4_block9_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_out (Activation)   (None, None, None, 1 0           conv4_block9_add[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, None, None, 2 262400      conv4_block9_out[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, None, None, 2 1024        conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, None, None, 2 0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, None, None, 2 590080      conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_bn (BatchNormal (None, None, None, 2 1024        conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_relu (Activatio (None, None, None, 2 0           conv4_block10_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_3_conv (Conv2D)   (None, None, None, 1 263168      conv4_block10_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_3_bn (BatchNormal (None, None, None, 1 4096        conv4_block10_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_add (Add)         (None, None, None, 1 0           conv4_block9_out[0][0]
#                                                                  conv4_block10_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_out (Activation)  (None, None, None, 1 0           conv4_block10_add[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, None, None, 2 262400      conv4_block10_out[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, None, None, 2 1024        conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, None, None, 2 0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, None, None, 2 590080      conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_bn (BatchNormal (None, None, None, 2 1024        conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_relu (Activatio (None, None, None, 2 0           conv4_block11_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_3_conv (Conv2D)   (None, None, None, 1 263168      conv4_block11_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_3_bn (BatchNormal (None, None, None, 1 4096        conv4_block11_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_add (Add)         (None, None, None, 1 0           conv4_block10_out[0][0]
#                                                                  conv4_block11_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_out (Activation)  (None, None, None, 1 0           conv4_block11_add[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, None, None, 2 262400      conv4_block11_out[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, None, None, 2 1024        conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, None, None, 2 0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, None, None, 2 590080      conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_bn (BatchNormal (None, None, None, 2 1024        conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_relu (Activatio (None, None, None, 2 0           conv4_block12_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_3_conv (Conv2D)   (None, None, None, 1 263168      conv4_block12_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_3_bn (BatchNormal (None, None, None, 1 4096        conv4_block12_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_add (Add)         (None, None, None, 1 0           conv4_block11_out[0][0]
#                                                                  conv4_block12_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_out (Activation)  (None, None, None, 1 0           conv4_block12_add[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_conv (Conv2D)   (None, None, None, 2 262400      conv4_block12_out[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_bn (BatchNormal (None, None, None, 2 1024        conv4_block13_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_relu (Activatio (None, None, None, 2 0           conv4_block13_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_conv (Conv2D)   (None, None, None, 2 590080      conv4_block13_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_bn (BatchNormal (None, None, None, 2 1024        conv4_block13_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_relu (Activatio (None, None, None, 2 0           conv4_block13_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_3_conv (Conv2D)   (None, None, None, 1 263168      conv4_block13_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_3_bn (BatchNormal (None, None, None, 1 4096        conv4_block13_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_add (Add)         (None, None, None, 1 0           conv4_block12_out[0][0]
#                                                                  conv4_block13_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_out (Activation)  (None, None, None, 1 0           conv4_block13_add[0][0]
# __________________________________________________________________________________________________
# conv4_block14_1_conv (Conv2D)   (None, None, None, 2 262400      conv4_block13_out[0][0]
# __________________________________________________________________________________________________
# conv4_block14_1_bn (BatchNormal (None, None, None, 2 1024        conv4_block14_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_1_relu (Activatio (None, None, None, 2 0           conv4_block14_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block14_2_conv (Conv2D)   (None, None, None, 2 590080      conv4_block14_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block14_2_bn (BatchNormal (None, None, None, 2 1024        conv4_block14_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_2_relu (Activatio (None, None, None, 2 0           conv4_block14_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block14_3_conv (Conv2D)   (None, None, None, 1 263168      conv4_block14_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block14_3_bn (BatchNormal (None, None, None, 1 4096        conv4_block14_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_add (Add)         (None, None, None, 1 0           conv4_block13_out[0][0]
#                                                                  conv4_block14_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block14_out (Activation)  (None, None, None, 1 0           conv4_block14_add[0][0]
# __________________________________________________________________________________________________
# conv4_block15_1_conv (Conv2D)   (None, None, None, 2 262400      conv4_block14_out[0][0]
# __________________________________________________________________________________________________
# conv4_block15_1_bn (BatchNormal (None, None, None, 2 1024        conv4_block15_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block15_1_relu (Activatio (None, None, None, 2 0           conv4_block15_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block15_2_conv (Conv2D)   (None, None, None, 2 590080      conv4_block15_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block15_2_bn (BatchNormal (None, None, None, 2 1024        conv4_block15_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block15_2_relu (Activatio (None, None, None, 2 0           conv4_block15_2_bn[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# conv4_block20_1_relu (Activatio (None, None, None, 2 0           conv4_block20_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block20_2_conv (Conv2D)   (None, None, None, 2 590080      conv4_block20_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block20_2_bn (BatchNormal (None, None, None, 2 1024        conv4_block20_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block20_2_relu (Activatio (None, None, None, 2 0           conv4_block20_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block20_3_conv (Conv2D)   (None, None, None, 1 263168      conv4_block20_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block20_3_bn (BatchNormal (None, None, None, 1 4096        conv4_block20_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block20_add (Add)         (None, None, None, 1 0           conv4_block19_out[0][0]
#                                                                  conv4_block20_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block20_out (Activation)  (None, None, None, 1 0           conv4_block20_add[0][0]
# __________________________________________________________________________________________________
# conv4_block21_1_conv (Conv2D)   (None, None, None, 2 262400      conv4_block20_out[0][0]
# __________________________________________________________________________________________________
# conv4_block21_1_bn (BatchNormal (None, None, None, 2 1024        conv4_block21_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block21_1_relu (Activatio (None, None, None, 2 0           conv4_block21_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block21_2_conv (Conv2D)   (None, None, None, 2 590080      conv4_block21_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block21_2_bn (BatchNormal (None, None, None, 2 1024        conv4_block21_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block21_2_relu (Activatio (None, None, None, 2 0           conv4_block21_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block21_3_conv (Conv2D)   (None, None, None, 1 263168      conv4_block21_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block21_3_bn (BatchNormal (None, None, None, 1 4096        conv4_block21_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block21_add (Add)         (None, None, None, 1 0           conv4_block20_out[0][0]
#                                                                  conv4_block21_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block21_out (Activation)  (None, None, None, 1 0           conv4_block21_add[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_conv (Conv2D)   (None, None, None, 2 262400      conv4_block21_out[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_bn (BatchNormal (None, None, None, 2 1024        conv4_block22_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_relu (Activatio (None, None, None, 2 0           conv4_block22_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_conv (Conv2D)   (None, None, None, 2 590080      conv4_block22_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_bn (BatchNormal (None, None, None, 2 1024        conv4_block22_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_relu (Activatio (None, None, None, 2 0           conv4_block22_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_3_conv (Conv2D)   (None, None, None, 1 263168      conv4_block22_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_3_bn (BatchNormal (None, None, None, 1 4096        conv4_block22_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_add (Add)         (None, None, None, 1 0           conv4_block21_out[0][0]
#                                                                  conv4_block22_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_out (Activation)  (None, None, None, 1 0           conv4_block22_add[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_conv (Conv2D)   (None, None, None, 2 262400      conv4_block22_out[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_bn (BatchNormal (None, None, None, 2 1024        conv4_block23_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_relu (Activatio (None, None, None, 2 0           conv4_block23_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_conv (Conv2D)   (None, None, None, 2 590080      conv4_block23_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_bn (BatchNormal (None, None, None, 2 1024        conv4_block23_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_relu (Activatio (None, None, None, 2 0           conv4_block23_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_3_conv (Conv2D)   (None, None, None, 1 263168      conv4_block23_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_3_bn (BatchNormal (None, None, None, 1 4096        conv4_block23_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_add (Add)         (None, None, None, 1 0           conv4_block22_out[0][0]
#                                                                  conv4_block23_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_out (Activation)  (None, None, None, 1 0           conv4_block23_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, None, None, 5 524800      conv4_block23_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, None, None, 5 0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, None, None, 5 2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, None, None, 5 0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, None, None, 2 2099200     conv4_block23_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, None, None, 2 8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, None, None, 2 8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, None, None, 2 0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, None, None, 2 0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, None, None, 5 1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, None, None, 5 0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, None, None, 5 2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, None, None, 5 0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, None, None, 2 8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, None, None, 2 0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, None, None, 2 0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, None, None, 5 1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, None, None, 5 0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, None, None, 5 2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, None, None, 5 0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, None, None, 2 8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, None, None, 2 0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, None, None, 2 0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# Dense0 (Dense)                  (None, 1000)         2049000     global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# Dense1 (Dense)                  (None, 1000)         1001000     Dense0[0][0]
# __________________________________________________________________________________________________
# dot (Dot)                       (None, 1)            0           Dense1[0][0]
#                                                                  Dense0[0][0]
# __________________________________________________________________________________________________
# salida (Dense)                  (None, 1)            2           dot[0][0]
# ==================================================================================================
# Total params: 45,708,178
# Trainable params: 45,602,834
# Non-trainable params: 105,344
# __________________________________________________________________________________________________

# %%
#SE CONGELAN LOS PESOS DE TODAS LAS CAPAS MENOS DE LAS cuatro ULTIMAS CAPAS
for layer in model.layers[:-4]:
  layer.trainable=False

# %%
#SE VERIFICA QUE LAS CUATRO ULTIMAS CAPAS ESTE EN TRUE Y LAS DEMÁS EN FALSE
for layer in model.layers:
  layer, layer.trainable
  print(layer, layer.trainable)
# Out:
# <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f815016e0b8> False
# <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f8180e34e80> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f8150152940> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f8150161588> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f815017eeb8> False
# <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f81500db7b8> False
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f81500a4630> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f8150120f60> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f815005f780> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f815005fef0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f81500668d0> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f815000bbe0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f8150012da0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f81501205c0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f8150012550> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f8150120978> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f8150041080> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f81500415c0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80fe174208> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80fe19a668> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80fe19a9b0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80fe1a0ba8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80fe1a0390> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80fe148ef0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80fe151f28> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80fe151748> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80fe0fe320> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80fe0fe860> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80fe107400> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80fe12c908> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80fe12cc88> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80fe131e48> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80fe1315f8> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80fe0e0128> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80fe0e09b0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80fe0e72e8> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80fe090ac8> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80fe090d30> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f815014bef0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f815c4f2f98> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f815c565048> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f815c565630> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f815c544fd0> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f815ca4bef0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f815ca55c50> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f81501529b0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f815ca556d8> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f815c4f2780> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f815c53b048> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f815c5c35c0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f815c5c35f8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80fe09f9e8> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80fe0a60b8> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80fe0a6940> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80fe0aa278> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f815ca96588> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f815ca96e10> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f815ca90780> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f815c581a90> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80fe036240> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80fe036c18> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80fe05ce80> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80fe062470> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80fe062cf8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80fe068668> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7fd7940> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7fdeb38> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7fde320> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7f83ef0> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e7f893c8> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7f89fd0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7fb54e0> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7fb5828> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7fb5f98> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7f3d908> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7f66d30> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7f6bef0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7f6b6a0> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7f1a240> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e7f1a780> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7f20320> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7ecf390> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7ef3eb8> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7efae10> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7efa5c0> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7ea7160> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7ea79e8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7ec8898> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7eb2320> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7ec8c18> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7e58668> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e7e58da0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7e5d7f0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7e06978> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7e0c048> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7e0c8d0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7e13208> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7e3a518> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7e3ada0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7dc0710> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7de8a20> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e7dec1d0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7decba8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7d95e10> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7d9b400> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7d9bc88> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7da25f8> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7d4c8d0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7d51ac8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7d512b0> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7d77e10> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e7cfe588> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7cfef60> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7d2e470> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7d2e7b8> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7d2eef0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7d35898> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7cdbcc0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7ce0e80> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7ce0630> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7c901d0> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e7c90710> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7c982b0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7c3c828> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7c3cba8> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7c42d68> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7c42518> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7c72080> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7c72908> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7c79240> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7c1e588> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e7c1eac8> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7c25668> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7bcdbe0> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7bcdfd0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7bd57f0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7bdc128> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7b82438> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7b82cc0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7b89630> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7baf940> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e7bb4128> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7bb4ac8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7b5dc50> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7b63320> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7b63ba8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7b694e0> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7b147f0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7b14f28> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7b1a8d0> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7ac0d30> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e7ac84a8> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7ac8e80> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7af5320> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7af56d8> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7af5eb8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7a7d8d0> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7aa0be0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7aa9da0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7aa9550> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7a570f0> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e7a57630> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7a5e278> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7a04748> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7a04a90> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7a0bc88> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7a0b470> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7a38470> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7a38828> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e79c0160> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e79e84a8> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e79e89e8> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e79ec588> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7994b00> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7994ef0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e799cf28> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e799c748> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7949358> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7949be0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7951550> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7976860> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e78fda20> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e78fd9e8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7924b70> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e792b240> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e792bac8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7933438> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e78db710> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e78dbef0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e78e18d0> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7887c50> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e78903c8> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7890da0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e78b4b70> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e783c5f8> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e783ce80> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e78457b8> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7868ac8> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e786ecc0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e786e470> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e781d1d0> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e781d550> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7826198> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e77cc668> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e77cc9b0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e77d3ba8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e77d3390> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e77faf28> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7781f60> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e77a6dd8> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e77af3c8> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e77af908> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e77b74a8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e775da20> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e775dda0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7763f28> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e77632e8> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7711278> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7711b00> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7719470> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e76c1780> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e76c1f60> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e76c4908> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e76eca90> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e76f2160> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e76f29e8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e767c320> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e76a2630> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e76a2eb8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e76aa828> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e764eb70> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e76542e8> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7654cc0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e75fcf28> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7606518> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7606da0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e760b710> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e76339e8> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7639be0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e76393c8> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e75def98> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e75e5470> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e75eb0b8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7591588> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e75918d0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e759bac8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e759b2b0> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7542dd8> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7547f98> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e75476a0> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e75782e8> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e7578828> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e74fe470> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7524940> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7524cc0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e752be80> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e752b630> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e74d9198> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e74d9a20> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e74e0390> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e74886a0> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e7488eb8> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e748d828> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e74b49b0> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e743c080> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e743c908> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7442240> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e746a550> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e746add8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7471748> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7417a58> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e741c208> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e741cbe0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e73c3e48> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e73cd438> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e73cdcc0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e73d4630> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e737c908> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7382b00> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e73822e8> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e73a5e48> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e73afef0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e73af710> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e735c4a8> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e735c7f0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e735cf28> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e73638d0> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e730bcf8> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7312eb8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7312668> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e72bf208> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e72bf748> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e72c62e8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e72ef860> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e72efbe0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e72f6da0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e72f6550> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e72a00b8> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e72a0940> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e72aa278> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e724d5c0> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e724db00> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7257748> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e71fec18> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7203470> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7203828> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7209160> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7234470> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7234cf8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e723a668> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e71df978> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e71e6128> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e71e6b00> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7194898> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7142278> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7142c18> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7149588> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7171898> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7177a58> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e718cc88> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7177048> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7194358> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e711bdd8> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e7121550> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7121f28> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e70d2438> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e70d2780> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e70d2eb8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e70d9358> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7080c88> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e7086e48> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e70865f8> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e70b4198> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e70b46d8> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e703c278> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e70647f0> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7064b70> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e706ad30> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e706a4e0> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e7014048> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e70148d0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f80e7022208> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f80e6fc5550> False
# <tensorflow.python.keras.layers.merge.Add object at 0x7f80e6fc5a90> False
# <tensorflow.python.keras.layers.core.Activation object at 0x7f80e6fcc630> False
# <tensorflow.python.keras.layers.pooling.GlobalAveragePooling2D object at 0x7f80e6fb9908> False
# <tensorflow.python.keras.layers.core.Dense object at 0x7f80e6fb9e80> True
# <tensorflow.python.keras.layers.core.Dense object at 0x7f80e6f0aa58> True
# <tensorflow.python.keras.layers.merge.Dot object at 0x7f80e6f0ab38> True
# <tensorflow.python.keras.layers.core.Dense object at 0x7f80e6f70b38> True

# %% [markdown]
# ##**6. Definir el optimizador para la funcion de costo, así como la funcion de pérdida y las metricas de evaluación del odelo a través de la compilacion del modelo.**
#
# Loss $\hspace{1em} \rightarrow \hspace{1em}$ $-ylog(x)\hat{y} + (1-y)log(1-\hat{y}) $

# %%
#DEFINIR OPTIMIZADOR, FUNCIONES DE PERIDA Y METRICAS
#optimizer = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)#, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
#loss='mean_squared_logariic_errorthm'
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['mse','mae','accuracy','Recall','Precision'])#,

# %% [markdown]
# ##**7. Entrenar el modelo con XTRAIN como un array de 4 dimensiones.**
#
# ---

# %%
print(len(XTRAIN),len(YTRAIN))
# Out:
# 1600 1600

# %%
#ENTRENAR EL MODELO CREADO
history=model.fit(XTRAIN,YTRAIN,epochs=250,batch_size=64)
# Out:
# Epoch 1/250
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 25/25 [==============================] - 4s 155ms/step - loss: 0.6132 - mse: 0.2115 - mae: 0.4469 - accuracy: 0.6800 - recall: 0.6425 - precision: 0.6946
# Epoch 2/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.5366 - mse: 0.1756 - mae: 0.3940 - accuracy: 0.7644 - recall: 0.7775 - precision: 0.7576
# Epoch 3/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.5077 - mse: 0.1624 - mae: 0.3753 - accuracy: 0.7975 - recall: 0.8112 - precision: 0.7895
# Epoch 4/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.4815 - mse: 0.1504 - mae: 0.3595 - accuracy: 0.8213 - recall: 0.8175 - precision: 0.8237
# Epoch 5/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.4586 - mse: 0.1400 - mae: 0.3462 - accuracy: 0.8438 - recall: 0.8487 - precision: 0.8403
# Epoch 6/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.4489 - mse: 0.1357 - mae: 0.3385 - accuracy: 0.8531 - recall: 0.8363 - precision: 0.8655
# Epoch 7/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.4312 - mse: 0.1278 - mae: 0.3278 - accuracy: 0.8637 - recall: 0.8575 - precision: 0.8684
# Epoch 8/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.4495 - mse: 0.1366 - mae: 0.3351 - accuracy: 0.8444 - recall: 0.8200 - precision: 0.8620
# Epoch 9/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.4015 - mse: 0.1147 - mae: 0.3094 - accuracy: 0.8919 - recall: 0.8863 - precision: 0.8963
# Epoch 10/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.3854 - mse: 0.1077 - mae: 0.2996 - accuracy: 0.9019 - recall: 0.8913 - precision: 0.9106
# Epoch 11/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.3679 - mse: 0.1001 - mae: 0.2888 - accuracy: 0.9169 - recall: 0.9025 - precision: 0.9292
# Epoch 12/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.3555 - mse: 0.0949 - mae: 0.2805 - accuracy: 0.9212 - recall: 0.9125 - precision: 0.9288
# Epoch 13/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.3534 - mse: 0.0945 - mae: 0.2782 - accuracy: 0.9175 - recall: 0.9087 - precision: 0.9249
# Epoch 14/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.3302 - mse: 0.0843 - mae: 0.2646 - accuracy: 0.9381 - recall: 0.9300 - precision: 0.9454
# Epoch 15/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.3127 - mse: 0.0770 - mae: 0.2532 - accuracy: 0.9475 - recall: 0.9362 - precision: 0.9578
# Epoch 16/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.2962 - mse: 0.0704 - mae: 0.2422 - accuracy: 0.9556 - recall: 0.9450 - precision: 0.9655
# Epoch 17/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.2995 - mse: 0.0725 - mae: 0.2431 - accuracy: 0.9469 - recall: 0.9337 - precision: 0.9589
# Epoch 18/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.2841 - mse: 0.0661 - mae: 0.2337 - accuracy: 0.9581 - recall: 0.9488 - precision: 0.9669
# Epoch 19/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.2842 - mse: 0.0666 - mae: 0.2329 - accuracy: 0.9513 - recall: 0.9488 - precision: 0.9535
# Epoch 20/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.2701 - mse: 0.0612 - mae: 0.2237 - accuracy: 0.9569 - recall: 0.9463 - precision: 0.9668
# Epoch 21/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.2598 - mse: 0.0571 - mae: 0.2169 - accuracy: 0.9631 - recall: 0.9588 - precision: 0.9672
# Epoch 22/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.2496 - mse: 0.0532 - mae: 0.2102 - accuracy: 0.9681 - recall: 0.9613 - precision: 0.9747
# Epoch 23/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.2404 - mse: 0.0501 - mae: 0.2033 - accuracy: 0.9694 - recall: 0.9650 - precision: 0.9735
# Epoch 24/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.2275 - mse: 0.0451 - mae: 0.1950 - accuracy: 0.9769 - recall: 0.9762 - precision: 0.9775
# Epoch 25/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.2159 - mse: 0.0410 - mae: 0.1868 - accuracy: 0.9794 - recall: 0.9787 - precision: 0.9800
# Epoch 26/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.2081 - mse: 0.0384 - mae: 0.1813 - accuracy: 0.9812 - recall: 0.9812 - precision: 0.9812
# Epoch 27/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.2011 - mse: 0.0359 - mae: 0.1764 - accuracy: 0.9844 - recall: 0.9850 - precision: 0.9838
# Epoch 28/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1935 - mse: 0.0334 - mae: 0.1708 - accuracy: 0.9869 - recall: 0.9875 - precision: 0.9863
# Epoch 29/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1877 - mse: 0.0316 - mae: 0.1666 - accuracy: 0.9881 - recall: 0.9887 - precision: 0.9875
# Epoch 30/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1806 - mse: 0.0293 - mae: 0.1614 - accuracy: 0.9894 - recall: 0.9912 - precision: 0.9875
# Epoch 31/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1753 - mse: 0.0276 - mae: 0.1576 - accuracy: 0.9925 - recall: 0.9962 - precision: 0.9888
# Epoch 32/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1725 - mse: 0.0267 - mae: 0.1556 - accuracy: 0.9937 - recall: 0.9975 - precision: 0.9901
# Epoch 33/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1636 - mse: 0.0242 - mae: 0.1484 - accuracy: 0.9937 - recall: 0.9975 - precision: 0.9901
# Epoch 34/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1585 - mse: 0.0228 - mae: 0.1443 - accuracy: 0.9944 - recall: 0.9987 - precision: 0.9901
# Epoch 35/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1540 - mse: 0.0216 - mae: 0.1405 - accuracy: 0.9944 - recall: 0.9987 - precision: 0.9901
# Epoch 36/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1504 - mse: 0.0207 - mae: 0.1376 - accuracy: 0.9944 - recall: 0.9987 - precision: 0.9901
# Epoch 37/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.1469 - mse: 0.0199 - mae: 0.1347 - accuracy: 0.9944 - recall: 0.9987 - precision: 0.9901
# Epoch 38/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1435 - mse: 0.0189 - mae: 0.1320 - accuracy: 0.9962 - recall: 1.0000 - precision: 0.9926
# Epoch 39/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1396 - mse: 0.0178 - mae: 0.1288 - accuracy: 0.9969 - recall: 1.0000 - precision: 0.9938
# Epoch 40/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1361 - mse: 0.0170 - mae: 0.1260 - accuracy: 0.9969 - recall: 1.0000 - precision: 0.9938
# Epoch 41/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1331 - mse: 0.0162 - mae: 0.1235 - accuracy: 0.9975 - recall: 1.0000 - precision: 0.9950
# Epoch 42/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.1298 - mse: 0.0154 - mae: 0.1208 - accuracy: 0.9975 - recall: 1.0000 - precision: 0.9950
# Epoch 43/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1265 - mse: 0.0146 - mae: 0.1182 - accuracy: 0.9981 - recall: 1.0000 - precision: 0.9963
# Epoch 44/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.1235 - mse: 0.0138 - mae: 0.1158 - accuracy: 0.9987 - recall: 1.0000 - precision: 0.9975
# Epoch 45/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1208 - mse: 0.0132 - mae: 0.1134 - accuracy: 0.9987 - recall: 1.0000 - precision: 0.9975
# Epoch 46/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1182 - mse: 0.0126 - mae: 0.1112 - accuracy: 0.9994 - recall: 1.0000 - precision: 0.9988
# Epoch 47/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.1155 - mse: 0.0121 - mae: 0.1089 - accuracy: 0.9994 - recall: 1.0000 - precision: 0.9988
# Epoch 48/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1132 - mse: 0.0116 - mae: 0.1069 - accuracy: 0.9994 - recall: 1.0000 - precision: 0.9988
# Epoch 49/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1108 - mse: 0.0110 - mae: 0.1049 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 50/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1085 - mse: 0.0106 - mae: 0.1028 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 51/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1064 - mse: 0.0102 - mae: 0.1010 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 52/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1045 - mse: 0.0098 - mae: 0.0992 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 53/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1026 - mse: 0.0095 - mae: 0.0975 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 54/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.1007 - mse: 0.0092 - mae: 0.0958 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 55/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0989 - mse: 0.0089 - mae: 0.0941 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 56/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0971 - mse: 0.0086 - mae: 0.0925 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 57/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0954 - mse: 0.0083 - mae: 0.0910 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 58/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0938 - mse: 0.0080 - mae: 0.0895 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 59/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0922 - mse: 0.0078 - mae: 0.0881 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 60/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0906 - mse: 0.0075 - mae: 0.0866 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 61/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0891 - mse: 0.0073 - mae: 0.0852 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 62/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0876 - mse: 0.0070 - mae: 0.0839 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 63/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0861 - mse: 0.0068 - mae: 0.0825 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 64/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0847 - mse: 0.0066 - mae: 0.0812 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 65/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0833 - mse: 0.0064 - mae: 0.0800 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 66/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0820 - mse: 0.0062 - mae: 0.0787 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 67/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0807 - mse: 0.0060 - mae: 0.0775 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 68/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0794 - mse: 0.0058 - mae: 0.0763 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 69/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0781 - mse: 0.0057 - mae: 0.0752 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 70/250
# 25/25 [==============================] - 4s 156ms/step - loss: 0.0769 - mse: 0.0055 - mae: 0.0740 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 71/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0756 - mse: 0.0053 - mae: 0.0729 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 72/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0745 - mse: 0.0052 - mae: 0.0717 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 73/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0733 - mse: 0.0050 - mae: 0.0707 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 74/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0721 - mse: 0.0048 - mae: 0.0696 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 75/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0710 - mse: 0.0047 - mae: 0.0686 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 76/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0699 - mse: 0.0046 - mae: 0.0676 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 77/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0689 - mse: 0.0044 - mae: 0.0666 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 78/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0678 - mse: 0.0043 - mae: 0.0656 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 79/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0668 - mse: 0.0042 - mae: 0.0646 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 80/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0658 - mse: 0.0041 - mae: 0.0637 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 81/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0648 - mse: 0.0039 - mae: 0.0628 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 82/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0639 - mse: 0.0038 - mae: 0.0619 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 83/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0629 - mse: 0.0037 - mae: 0.0610 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 84/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0620 - mse: 0.0036 - mae: 0.0601 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 85/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0611 - mse: 0.0035 - mae: 0.0593 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 86/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0602 - mse: 0.0034 - mae: 0.0584 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 87/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0593 - mse: 0.0033 - mae: 0.0576 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 88/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0585 - mse: 0.0032 - mae: 0.0568 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 89/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0576 - mse: 0.0031 - mae: 0.0560 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 90/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0568 - mse: 0.0031 - mae: 0.0552 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 91/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0560 - mse: 0.0030 - mae: 0.0545 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 92/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0552 - mse: 0.0029 - mae: 0.0537 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 93/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0544 - mse: 0.0028 - mae: 0.0530 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 94/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0537 - mse: 0.0027 - mae: 0.0522 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 95/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0529 - mse: 0.0027 - mae: 0.0515 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 96/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0522 - mse: 0.0026 - mae: 0.0508 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 97/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0515 - mse: 0.0025 - mae: 0.0502 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 98/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0508 - mse: 0.0025 - mae: 0.0495 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 99/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0501 - mse: 0.0024 - mae: 0.0488 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 100/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0494 - mse: 0.0023 - mae: 0.0482 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 101/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0487 - mse: 0.0023 - mae: 0.0475 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 102/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0480 - mse: 0.0022 - mae: 0.0469 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 103/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0474 - mse: 0.0021 - mae: 0.0463 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 104/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0467 - mse: 0.0021 - mae: 0.0457 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 105/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0461 - mse: 0.0020 - mae: 0.0451 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 106/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0455 - mse: 0.0020 - mae: 0.0445 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 107/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0449 - mse: 0.0019 - mae: 0.0439 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 108/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0443 - mse: 0.0019 - mae: 0.0433 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 109/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0437 - mse: 0.0018 - mae: 0.0428 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 110/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0431 - mse: 0.0018 - mae: 0.0422 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 111/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0426 - mse: 0.0017 - mae: 0.0417 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 112/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0420 - mse: 0.0017 - mae: 0.0411 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 113/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0414 - mse: 0.0016 - mae: 0.0406 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 114/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0409 - mse: 0.0016 - mae: 0.0401 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 115/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0404 - mse: 0.0016 - mae: 0.0396 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 116/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0399 - mse: 0.0015 - mae: 0.0391 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 117/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0393 - mse: 0.0015 - mae: 0.0386 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 118/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0388 - mse: 0.0015 - mae: 0.0381 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 119/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0383 - mse: 0.0014 - mae: 0.0376 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 120/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0378 - mse: 0.0014 - mae: 0.0371 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 121/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0374 - mse: 0.0013 - mae: 0.0367 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 122/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0369 - mse: 0.0013 - mae: 0.0362 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 123/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0364 - mse: 0.0013 - mae: 0.0358 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 124/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0359 - mse: 0.0012 - mae: 0.0353 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 125/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0355 - mse: 0.0012 - mae: 0.0349 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 126/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0350 - mse: 0.0012 - mae: 0.0344 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 127/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0346 - mse: 0.0012 - mae: 0.0340 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 128/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0342 - mse: 0.0011 - mae: 0.0336 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 129/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0337 - mse: 0.0011 - mae: 0.0332 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 130/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0333 - mse: 0.0011 - mae: 0.0328 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 131/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0329 - mse: 0.0010 - mae: 0.0324 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 132/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0325 - mse: 0.0010 - mae: 0.0320 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 133/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0321 - mse: 9.9803e-04 - mae: 0.0316 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 134/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0317 - mse: 9.7314e-04 - mae: 0.0312 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 135/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0313 - mse: 9.4936e-04 - mae: 0.0308 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 136/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0309 - mse: 9.2661e-04 - mae: 0.0304 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 137/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0305 - mse: 9.0441e-04 - mae: 0.0301 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 138/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0302 - mse: 8.8274e-04 - mae: 0.0297 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 139/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0298 - mse: 8.6136e-04 - mae: 0.0293 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 140/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0294 - mse: 8.4071e-04 - mae: 0.0290 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 141/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0291 - mse: 8.2078e-04 - mae: 0.0286 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 142/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0287 - mse: 8.0115e-04 - mae: 0.0283 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 143/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0284 - mse: 7.8211e-04 - mae: 0.0280 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 144/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0280 - mse: 7.6361e-04 - mae: 0.0276 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 145/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0277 - mse: 7.4541e-04 - mae: 0.0273 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 146/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0273 - mse: 7.2789e-04 - mae: 0.0270 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 147/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0270 - mse: 7.1080e-04 - mae: 0.0267 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 148/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0267 - mse: 6.9396e-04 - mae: 0.0263 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 149/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0264 - mse: 6.7771e-04 - mae: 0.0260 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 150/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0261 - mse: 6.6177e-04 - mae: 0.0257 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 151/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0257 - mse: 6.4631e-04 - mae: 0.0254 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 152/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0254 - mse: 6.3120e-04 - mae: 0.0251 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 153/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0251 - mse: 6.1643e-04 - mae: 0.0248 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 154/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0248 - mse: 6.0206e-04 - mae: 0.0245 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 155/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0245 - mse: 5.8812e-04 - mae: 0.0242 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 156/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0243 - mse: 5.7441e-04 - mae: 0.0240 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 157/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0240 - mse: 5.6105e-04 - mae: 0.0237 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 158/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0237 - mse: 5.4806e-04 - mae: 0.0234 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 159/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0234 - mse: 5.3541e-04 - mae: 0.0231 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 160/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0231 - mse: 5.2313e-04 - mae: 0.0229 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 161/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0229 - mse: 5.1105e-04 - mae: 0.0226 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 162/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0226 - mse: 4.9926e-04 - mae: 0.0223 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 163/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0223 - mse: 4.8779e-04 - mae: 0.0221 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 164/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0221 - mse: 4.7666e-04 - mae: 0.0218 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 165/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0218 - mse: 4.6569e-04 - mae: 0.0216 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 166/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0216 - mse: 4.5500e-04 - mae: 0.0213 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 167/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0213 - mse: 4.4461e-04 - mae: 0.0211 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 168/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0211 - mse: 4.3457e-04 - mae: 0.0208 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 169/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0208 - mse: 4.2459e-04 - mae: 0.0206 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 170/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0206 - mse: 4.1493e-04 - mae: 0.0204 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 171/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0203 - mse: 4.0549e-04 - mae: 0.0201 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 172/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0201 - mse: 3.9626e-04 - mae: 0.0199 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 173/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0199 - mse: 3.8722e-04 - mae: 0.0197 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 174/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0196 - mse: 3.7827e-04 - mae: 0.0194 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 175/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0194 - mse: 3.6980e-04 - mae: 0.0192 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 176/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0192 - mse: 3.6138e-04 - mae: 0.0190 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 177/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0190 - mse: 3.5314e-04 - mae: 0.0188 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 178/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0188 - mse: 3.4520e-04 - mae: 0.0186 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 179/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0185 - mse: 3.3739e-04 - mae: 0.0184 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 180/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0183 - mse: 3.2983e-04 - mae: 0.0182 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 181/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0181 - mse: 3.2240e-04 - mae: 0.0180 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 182/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0179 - mse: 3.1524e-04 - mae: 0.0178 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 183/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0177 - mse: 3.0814e-04 - mae: 0.0176 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 184/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0175 - mse: 3.0128e-04 - mae: 0.0174 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 185/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0173 - mse: 2.9451e-04 - mae: 0.0172 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 186/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0171 - mse: 2.8793e-04 - mae: 0.0170 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 187/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0169 - mse: 2.8154e-04 - mae: 0.0168 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 188/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0167 - mse: 2.7526e-04 - mae: 0.0166 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 189/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0165 - mse: 2.6911e-04 - mae: 0.0164 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 190/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0164 - mse: 2.6312e-04 - mae: 0.0162 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 191/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0162 - mse: 2.5722e-04 - mae: 0.0160 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 192/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0160 - mse: 2.5145e-04 - mae: 0.0159 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 193/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0158 - mse: 2.4587e-04 - mae: 0.0157 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 194/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0156 - mse: 2.4044e-04 - mae: 0.0155 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 195/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0154 - mse: 2.3509e-04 - mae: 0.0153 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 196/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0153 - mse: 2.2991e-04 - mae: 0.0152 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 197/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0151 - mse: 2.2485e-04 - mae: 0.0150 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 198/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0149 - mse: 2.1986e-04 - mae: 0.0148 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 199/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0148 - mse: 2.1504e-04 - mae: 0.0147 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 200/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0146 - mse: 2.1030e-04 - mae: 0.0145 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 201/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0144 - mse: 2.0565e-04 - mae: 0.0143 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 202/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0143 - mse: 2.0118e-04 - mae: 0.0142 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 203/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0141 - mse: 1.9677e-04 - mae: 0.0140 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 204/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0140 - mse: 1.9242e-04 - mae: 0.0139 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 205/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0138 - mse: 1.8824e-04 - mae: 0.0137 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 206/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0137 - mse: 1.8412e-04 - mae: 0.0136 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 207/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0135 - mse: 1.8006e-04 - mae: 0.0134 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 208/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0134 - mse: 1.7613e-04 - mae: 0.0133 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 209/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0132 - mse: 1.7228e-04 - mae: 0.0131 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 210/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0131 - mse: 1.6851e-04 - mae: 0.0130 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 211/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0129 - mse: 1.6483e-04 - mae: 0.0128 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 212/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0128 - mse: 1.6124e-04 - mae: 0.0127 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 213/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0126 - mse: 1.5773e-04 - mae: 0.0126 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 214/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0125 - mse: 1.5434e-04 - mae: 0.0124 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 215/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0124 - mse: 1.5098e-04 - mae: 0.0123 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 216/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0122 - mse: 1.4766e-04 - mae: 0.0122 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 217/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0121 - mse: 1.4449e-04 - mae: 0.0120 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 218/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0120 - mse: 1.4133e-04 - mae: 0.0119 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 219/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0118 - mse: 1.3826e-04 - mae: 0.0118 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 220/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0117 - mse: 1.3527e-04 - mae: 0.0116 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 221/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0116 - mse: 1.3236e-04 - mae: 0.0115 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 222/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0114 - mse: 1.2948e-04 - mae: 0.0114 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 223/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0113 - mse: 1.2668e-04 - mae: 0.0113 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 224/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0112 - mse: 1.2394e-04 - mae: 0.0111 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 225/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0111 - mse: 1.2127e-04 - mae: 0.0110 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 226/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0110 - mse: 1.1865e-04 - mae: 0.0109 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 227/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0108 - mse: 1.1610e-04 - mae: 0.0108 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 228/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0107 - mse: 1.1358e-04 - mae: 0.0107 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 229/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0106 - mse: 1.1115e-04 - mae: 0.0105 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 230/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0105 - mse: 1.0875e-04 - mae: 0.0104 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 231/250
# 25/25 [==============================] - 4s 156ms/step - loss: 0.0104 - mse: 1.0641e-04 - mae: 0.0103 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 232/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0103 - mse: 1.0413e-04 - mae: 0.0102 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 233/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0101 - mse: 1.0188e-04 - mae: 0.0101 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 234/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0100 - mse: 9.9697e-05 - mae: 0.0100 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 235/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0099 - mse: 9.7562e-05 - mae: 0.0099 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 236/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0098 - mse: 9.5466e-05 - mae: 0.0098 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 237/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0097 - mse: 9.3430e-05 - mae: 0.0097 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 238/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0096 - mse: 9.1417e-05 - mae: 0.0096 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 239/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0095 - mse: 8.9470e-05 - mae: 0.0095 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 240/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0094 - mse: 8.7552e-05 - mae: 0.0094 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 241/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0093 - mse: 8.5684e-05 - mae: 0.0093 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 242/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0092 - mse: 8.3841e-05 - mae: 0.0092 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 243/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0091 - mse: 8.2054e-05 - mae: 0.0091 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 244/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0090 - mse: 8.0306e-05 - mae: 0.0090 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 245/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0089 - mse: 7.8596e-05 - mae: 0.0089 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 246/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0088 - mse: 7.6905e-05 - mae: 0.0088 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 247/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0087 - mse: 7.5271e-05 - mae: 0.0087 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 248/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0086 - mse: 7.3666e-05 - mae: 0.0086 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 249/250
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0085 - mse: 7.2094e-05 - mae: 0.0085 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000
# Epoch 250/250
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0084 - mse: 7.0568e-05 - mae: 0.0084 - accuracy: 1.0000 - recall: 1.0000 - precision: 1.0000

# %% [markdown]
# ##**8. Generar gráfica de: loss(pérdida) y accuracy(acierto) en cada época realizada.**

# %%
import pandas as pd

pd.DataFrame(history.history).plot(figsize=(8, 6))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %% [markdown]
# ##**9. Predecir con el modelo, la clasificación de cada imagen del conjunto de Test**

# %%
#SE EVALÚA EL MODELO

Valores=(model.predict(XTEST))
#Valores

# %%
#Valores_label=np.argmax(Valores, axis=1)
#Valores_label
Valores_label=np.around(Valores)
Valores_label.shape
# Out:
# (400, 1)

# %% [markdown]
# ##**10. Sacar métricas de evaluación, para mirar el rendimiento del modelo.**

# %% [markdown]
# > **A. Matriz de confusión simple.**

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

#YTEST=YTEST.reshape(len(Ytest),1)

acc = accuracy_score(YTEST,Valores_label)
print('acierto: ',acc)
cm=confusion_matrix(YTEST,Valores_label)
cm
# Out:
# acierto:  0.76
# array([[150,  50],
#        [ 46, 154]])

# %% [markdown]
# >**B. Matriz de confusión, con porcentjes de acierto.**

# %%
from sklearn.utils.multiclass import unique_labels


def plot_confusion_matrix(matrix,Ytest,Valores_label,acc,Valores2):
    fig = plt.figure(figsize=(5,5))
    ax = fig.add_subplot(111)
    cmap=plt.cm.Blues
    matrix = 100*matrix.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    cax = ax.matshow(matrix, interpolation='nearest', cmap=cmap)
    fig.colorbar(cax)
    classes = unique_labels(Ytest,Valores_label)
    classes1= Valores2
    ax.set(xticks=np.arange(matrix.shape[1]),
           yticks=np.arange(matrix.shape[0]),
           xticklabels=classes1, yticklabels=classes1,
           title='ACC = %.1f %%' % (100*acc),
           ylabel='True label',
           xlabel='Predicted label')
    fmt = '.1f'
    thresh = matrix.max() / 2.
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(j, i, format(matrix[i, j], fmt),
                    ha="center", va="center",
                    color="black",fontsize=14)
    fig.tight_layout()

#Valores_label_texto=convertir_salida_texto(Valores_label)
plot_confusion_matrix(cm,YTEST,Valores_label,acc,Valores2=["Perro","Gato"])

# %% [markdown]
# > **C. Reporte de algunas métricas: Precisión, recall, F1 y Support, para el umbral de clasificación 0,5(por defecto usado por keras).**

# %%
from sklearn.metrics import classification_report

target_names = ['Perro', 'Gato']
cr=classification_report(YTEST, Valores_label,labels=range(len(target_names)),target_names=target_names)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#        Perro       0.77      0.75      0.76       200
#         Gato       0.75      0.77      0.76       200
#
#     accuracy                           0.76       400
#    macro avg       0.76      0.76      0.76       400
# weighted avg       0.76      0.76      0.76       400

# %% [markdown]
# >**D. Curva ROC, para cada clase, variando los umbrales de decisión(Thresold) o, en este caso con la probabilidad de que pertenezca a una de las salidas.**

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc



Ytest_Bin= label_binarize(YTEST, classes=[0,1])
Valores_Bin= label_binarize(Valores_label, classes=[0,1])
roc_auc, fpr, tpr, n_classes = roc_multiclass(Ytest_Bin,Valores_Bin,colum=1)
roc_auc_mc(roc_auc,fpr,tpr,n_classes,'ROC curve ')

# %%
#GRAFICAR LAS PRIMERAS 10 CLASES
tam=10
index=0
plt.figure(figsize=(tam*2, 7))
for i in range(1,tam):
  index += 1
  plt.subplot((tam//10)+1, 5, index)
  plt.imshow(XTEST[i-1])
  plt.title("Class: {}".format(Valores_label[i-1]))
  plt.axis("off")
plt.show()
